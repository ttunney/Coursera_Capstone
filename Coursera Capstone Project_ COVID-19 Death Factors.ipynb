# %% [markdown]
# <h3> This notebook will be used primarily for the Coursera Capstone project. This project will use a data set from the National Center for Health Statistics. The data set is called "Conditions contributing to deaths involving coronavirus disease 2019 (COVID-19), by age group and state, United States." This data set was created on 8 May 2020. It includes 10 attributes and 12.3K tuples.<h3>

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course")
# Out:
# Hello Capstone Project Course
